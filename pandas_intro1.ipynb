# %%
import pandas as pd
import numpy as np

# %%
student_df = pd.read_csv('new_students.csv')
people_df=pd.read_excel('pepole_redi.xlsx')

# %%
course_df=pd.read_excel('pepole_redi.xlsx', sheet_name='Course')

# %% [markdown]
# ## Checking Data

# %%
student_df.head(2)
# Out:
#    id   name lastname nationality
# 0   1  Bahar     zare        Iran
# 1   2  Bahar  Heidari        Iran

# %%
student_df.tail()
# Out:
#    id      name   lastname nationality
# 4   5      Anna  Jørgensen     Denmark
# 5   6      Anna  Jørgensen     denmark
# 6   7
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9 non-null      int64
#  1   name         9 non-null      object
#  2   lastname     8 non-null      object
#  3   nationality  9 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 420.0+ bytes

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            15 non-null     object
#  1   last name       15 non-null     object
#  2   age             13 non-null     float64
#  3   course_id       15 non-null     int64
#  4   Gender          14 non-null     object
#  5   nationality     15 non-null     object
#  6   postal code     13 non-null     float64
#  7   address         2 non-null      object
#  8   mobile number   15 non-null     object
#  9   Type            14 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.3+ KB

# %%
people_df.isna().sum()
# Out:
# name               0
# last name          0
# age                2
# course_id          0
# Gender             1
# nationality        0
# postal code        2
# address           13
# mobile number      0
# Type               1
# dtype: int64

# %%
people_df.isna().sum()[people_df.isna().sum()>0]
# Out:
# age             2
# Gender          1
# postal code     2
# address        13
# Type            1
# dtype: int64

# %%
len(people_df)
# Out:
# 15

# %%
student_df.isna().sum()[student_df.isna().sum()>0]
# Out:
# lastname    1
# dtype: int64

# %%
student_df[2:-2][['name','lastname']]
# Out:
#    name   lastname
# 2  Tara   Anderson
# 3  Raha      Gerde
# 4  Anna  Jørgensen
# 5  Anna  Jørgensen
# 6

# %%
student_df[student_df.name=='Anna']
# Out:
#    id  name   lastname nationality
# 4   5  Anna  Jørgensen     Denmark
# 5   6  Anna  Jørgensen     denmark

# %%
student_df.duplicated('name')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
student_df[student_df.duplicated('name')]
# Out:
#    id   name   lastname nationality
# 1   2  Bahar    Heidari        Iran
# 5   6   Anna  Jørgensen     denmark

# %% [markdown]
# ## describe

# %%
student_df[student_df.name=='Anna']
# Out:
#    id  name   lastname nationality
# 4   5  Anna  Jørgensen     Denmark
# 5   6  Anna  Jørgensen     denmark

# %%
people_df.describe()
# Out:
#              age  course_id  postal code
# count  13.000000  15.000000    13.000000
# mean   34.230769   3.066667  2925.000000
# std    21.071916   3.692979  1223.105678
# min     1.000000   1.000000  1400.000000
# 25%    25.000000   1.000000  2300.000000
# 50%    30.000000   2.000000  2400.000000
# 75%    45.000000   2.500000  3500.000000
# max    90.000000  12.000000  5255.000000

# %%
people_df.describe().T
# Out:
#              count         mean          std     min     25%     50%     75%  \
# age           13.0    34.230769    21.071916     1.0    25.0    30.0    45.0
# course_id     15.0     3.066667     3.692979     1.0     1.0     2.0     2.5
# postal code   13.0  2925.000000  1223.105678  1400.0  2300.0  2400.0  3500.0
#
#                 max
# age            90.0
# course_id      12.0
# postal code  5255.0

# %%
people_df.describe(include='all')
# Out:
#         name last name        age  course_id Gender nationality  postal code  \
# count     15        15  13.000000  15.000000     14          15    13.000000
# unique    14        13        NaN        NaN      5          12          NaN
# top     Nana    karimi        NaN        NaN      f         USA          NaN
# freq       2         2        NaN        NaN      6           2          NaN
# mean     NaN       NaN  34.230769   3.066667    NaN         NaN  2925.000000
# std      NaN       NaN  21.071916   3.692979    NaN         NaN  1223.105678
# min      NaN       NaN   1.000000   1.000000    NaN         NaN  1400.000000
# 25%      NaN       NaN  25.000000   1.000000    NaN         NaN  2300.000000
# 50%      NaN       NaN  30.000000   2.000000    NaN         NaN  2400.000000
# 75%      NaN       NaN  45.000000   2.500000    NaN         NaN  3500.000000
# max      NaN       NaN  90.000000  12.000000    NaN         NaN  5255.000000
#
# ...

# %%
people_df.describe(include =[int])
# Out:
#        course_id
# count  15.000000
# mean    3.066667
# std     3.692979
# min     1.000000
# 25%     1.000000
# 50%     2.000000
# 75%     2.500000
# max    12.000000

# %%
people_df.describe(exclude=[int])
# Out:
#         name last name        age Gender nationality  postal code  \
# count     15        15  13.000000     14          15    13.000000
# unique    14        13        NaN      5          12          NaN
# top     Nana    karimi        NaN      f         USA          NaN
# freq       2         2        NaN      6           2          NaN
# mean     NaN       NaN  34.230769    NaN         NaN  2925.000000
# std      NaN       NaN  21.071916    NaN         NaN  1223.105678
# min      NaN       NaN   1.000000    NaN         NaN  1400.000000
# 25%      NaN       NaN  25.000000    NaN         NaN  2300.000000
# 50%      NaN       NaN  30.000000    NaN         NaN  2400.000000
# 75%      NaN       NaN  45.000000    NaN         NaN  3500.000000
# max      NaN       NaN  90.000000    NaN         NaN  5255.000000
#
#              address  mobile number      Type
# count              2    1.500000e+01       14
# unique             2    1.400000e+01        2
# ...

# %% [markdown]
# ## Reading columns

# %%
people_df.columns
# Out:
# Index(['name', 'last name', 'age', 'course_id', 'Gender', 'nationality',
#        'postal code', 'address', 'mobile number ', 'Type'],
#       dtype='object')

# %%
people_df['last name']
# Out:
# 0       andersen
# 1          Noori
# 2          juicy
# 3        Heidari
# 4      Jørgensen
# 5         karimi
# 6       shabnami
# 7     raju zadeh
# 8       moghadam
# 9     emilderson
# 10        karimi
# 11       niknami
# 12    fredriksen
# 13          abdi
# 14    emilderson
# Name: last name, dtype: object

# %%
people_df.name
# Out:
# 0         Tala
# 1         Mary
# 2          Joe
# 3          Ati
# 4      AmirAli
# 5       Jørgen
# 6        Bahar
# 7         Raju
# 8     Ashwaria
# 9         Nana
# 10        Niki
# 11        Rosa
# 12       Mette
# 13    Louretta
# 14        Nana
# Name: name, dtype: object

# %%
people_df[['name','last name','address']]
# Out:
#         name   last name       address
# 0       Tala    andersen  Else Alfelts
# 1       Mary       Noori           NaN
# 2        Joe       juicy     Nørreport
# 3        Ati     Heidari           NaN
# 4    AmirAli   Jørgensen           NaN
# 5     Jørgen      karimi           NaN
# 6      Bahar    shabnami           NaN
# 7       Raju  raju zadeh           NaN
# 8   Ashwaria    moghadam           NaN
# 9       Nana  emilderson           NaN
# 10      Niki      karimi           NaN
# 11      Rosa     niknami           NaN
# 12     Mette  fredriksen           NaN
# 13  Louretta        abdi           NaN
# 14      Nana  emilderson           NaN

# %%
people_df[2:-2][['name','last name']]
# Out:
#         name   last name
# 2        Joe       juicy
# 3        Ati     Heidari
# 4    AmirAli   Jørgensen
# 5     Jørgen      karimi
# 6      Bahar    shabnami
# 7       Raju  raju zadeh
# 8   Ashwaria    moghadam
# 9       Nana  emilderson
# 10      Niki      karimi
# 11      Rosa     niknami
# 12     Mette  fredriksen

# %%
list(people_df.columns)
# Out:
# ['name',
#  'last name',
#  'age',
#  'course_id',
#  'Gender',
#  'nationality',
#  'postal code',
#  'address',
#  'mobile number ',
#  'Type']

# %%
people_df.loc

# %%
people_df.iloc

# %%
pp_df= people_df.copy()
pp_df
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1      F     Denmark       2300.0
# 1       Mary       Noori   1.0          2      f         USA       1400.0
# 2        Joe       juicy  20.0          1      m         USA       2000.0
# 3        Ati     Heidari  34.0          2      f        Iran       2500.0
# 4    AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5     Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 6      Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 7       Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 8   Ashwaria    moghadam  30.0          2      F       India       2045.0
# 9       Nana  emilderson  45.0         12      f      Sweden       5255.0
# 10      Niki      karimi  28.0          3      F          UK          NaN
# 11      Rosa     niknami  30.0          3     F         Iran       2300.0
# ...

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            15 non-null     object
#  1   last name       15 non-null     object
#  2   age             13 non-null     float64
#  3   course_id       15 non-null     int64
#  4   Gender          14 non-null     object
#  5   nationality     15 non-null     object
#  6   postal code     13 non-null     float64
#  7   address         2 non-null      object
#  8   mobile number   15 non-null     object
#  9   Type            14 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.3+ KB

# %%
pp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            15 non-null     object
#  1   last name       15 non-null     object
#  2   age             13 non-null     float64
#  3   course_id       15 non-null     int64
#  4   Gender          14 non-null     object
#  5   nationality     15 non-null     object
#  6   postal code     13 non-null     float64
#  7   address         2 non-null      object
#  8   mobile number   15 non-null     object
#  9   Type            14 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.3+ KB

# %% [markdown]
# ## isna() & isnull()

# %%
pp_df.isna().head(7)
# Out:
#     name  last name    age  course_id  Gender  nationality  postal code  \
# 0  False      False  False      False   False        False        False
# 1  False      False  False      False   False        False        False
# 2  False      False  False      False   False        False        False
# 3  False      False  False      False   False        False        False
# 4  False      False  False      False   False        False        False
# 5  False      False  False      False   False        False         True
# 6  False      False   True      False   False        False        False
#
#    address  mobile number    Type
# 0    False           False  False
# 1     True           False  False
# 2    False           False  False
# 3     True           False  False
# 4     True           False   True
# 5     True           False  False
# 6     True           False  False

# %%
pp_df.isnull()
# Out:
#      name  last name    age  course_id  Gender  nationality  postal code  \
# 0   False      False  False      False   False        False        False
# 1   False      False  False      False   False        False        False
# 2   False      False  False      False   False        False        False
# 3   False      False  False      False   False        False        False
# 4   False      False  False      False   False        False        False
# 5   False      False  False      False   False        False         True
# 6   False      False   True      False   False        False        False
# 7   False      False  False      False    True        False        False
# 8   False      False  False      False   False        False        False
# 9   False      False  False      False   False        False        False
# 10  False      False  False      False   False        False         True
# 11  False      False  False      False   False        False        False
# ...

# %%
pp_df.isna().sum()
# Out:
# name               0
# last name          0
# age                2
# course_id          0
# Gender             1
# nationality        0
# postal code        2
# address           13
# mobile number      0
# Type               1
# dtype: int64

# %%
pp_df.isna().sum().sum()
# Out:
# 19

# %% [markdown]
# ## index

# %%
pp_df[pp_df.index==1]
# Out:
#    name last name  age  course_id Gender nationality  postal code address  \
# 1  Mary     Noori  1.0          2      f         USA       1400.0     NaN
#
#   mobile number      Type
# 1      542121214  Student

# %%
pp_df[pp_df.index.isin(range(2,10))]
# Out:
#        name   last name   age  course_id Gender nationality  postal code  \
# 2       Joe       juicy  20.0          1      m         USA       2000.0
# 3       Ati     Heidari  34.0          2      f        Iran       2500.0
# 4   AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5    Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 6     Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 7      Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 8  Ashwaria    moghadam  30.0          2      F       India       2045.0
# 9      Nana  emilderson  45.0         12      f      Sweden       5255.0
#
#      address   mobile number      Type
# 2  Nørreport  54554254254f454  Student
# 3        NaN        250005555  Student
# 4        NaN                9      NaN
# 5        NaN       5822222443  Student
# 6        NaN       8522222444  Student
# 7        NaN       6662222445  Student
# ...

# %%
pp_df.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %% [markdown]
# ## loc & iloc

# %%
pp_df.loc[1]
# Out:
# name                   Mary
# last name             Noori
# age                     1.0
# course_id                 2
# Gender                    f
# nationality             USA
# postal code          1400.0
# address                 NaN
# mobile number     542121214
# Type                Student
# Name: 1, dtype: object

# %%
pp_df.iloc[1]
# Out:
# name                   Mary
# last name             Noori
# age                     1.0
# course_id                 2
# Gender                    f
# nationality             USA
# postal code          1400.0
# address                 NaN
# mobile number     542121214
# Type                Student
# Name: 1, dtype: object

# %%
pp_df
# Out:
#      last name  course_id Gender nationality  postal code       address  \
# 0     andersen          1      F     Denmark       2300.0  Else Alfelts
# 1        Noori          2      f         USA       1400.0           NaN
# 2        juicy          1      m         USA       2000.0     Nørreport
# 3      Heidari          2      f        Iran       2500.0           NaN
# 4    Jørgensen          1      M      France       2770.0           NaN
# 5       karimi          1      m     Denamrk          NaN           NaN
# 6     shabnami          2      F      Turkey       3500.0           NaN
# 7   raju zadeh          1    NaN       India       2300.0           NaN
# 8     moghadam          2      F       India       2045.0           NaN
# 9   emilderson         12      f      Sweden       5255.0           NaN
# 10      karimi          3      F          UK          NaN           NaN
# 11     niknami          3     F         Iran       2300.0           NaN
# ...

# %%
pp_df.reset_index(drop=True,inplace=True)

# %%
pp_df
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1      F     Denmark       2300.0
# 1       Mary       Noori   1.0          2      f         USA       1400.0
# 2        Joe       juicy  20.0          1      m         USA       2000.0
# 3        Ati     Heidari  34.0          2      f        Iran       2500.0
# 4    AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5     Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 6      Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 7       Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 8   Ashwaria    moghadam  30.0          2      F       India       2045.0
# 9       Nana  emilderson  45.0         12      f      Sweden       5255.0
# 10      Niki      karimi  28.0          3      F          UK          NaN
# 11      Rosa     niknami  30.0          3     F         Iran       2300.0
# ...

# %%
pp_df.loc['Bahar']
# Out:
# last name           shabnami
# course_id                  2
# Gender                     F
# nationality           Turkey
# postal code           3500.0
# address                  NaN
# mobile number     8522222444
# Type                 Student
# Name: Bahar, dtype: object

# %%
pp_df.loc[2:7]
# Out:
#       name   last name   age  course_id Gender nationality  postal code  \
# 2      Joe       juicy  20.0          1      m         USA       2000.0
# 3      Ati     Heidari  34.0          2      f        Iran       2500.0
# 4  AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5   Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 6    Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 7     Raju  raju zadeh  25.0          1    NaN       India       2300.0
#
#      address   mobile number      Type
# 2  Nørreport  54554254254f454  Student
# 3        NaN        250005555  Student
# 4        NaN                9      NaN
# 5        NaN       5822222443  Student
# 6        NaN       8522222444  Student
# 7        NaN       6662222445  Student

# %%
pp_df.iloc[2:7]
# Out:
#       name  last name   age  course_id Gender nationality  postal code  \
# 2      Joe      juicy  20.0          1      m         USA       2000.0
# 3      Ati    Heidari  34.0          2      f        Iran       2500.0
# 4  AmirAli  Jørgensen  19.0          1      M      France       2770.0
# 5   Jørgen     karimi  50.0          1      m     Denamrk          NaN
# 6    Bahar   shabnami   NaN          2      F      Turkey       3500.0
#
#      address   mobile number      Type
# 2  Nørreport  54554254254f454  Student
# 3        NaN        250005555  Student
# 4        NaN                9      NaN
# 5        NaN       5822222443  Student
# 6        NaN       8522222444  Student

# %%
pp_df.iloc[[1,5,10]]
# Out:
#       name last name   age  course_id Gender nationality  postal code address  \
# 1     Mary     Noori   1.0          2      f         USA       1400.0     NaN
# 5   Jørgen    karimi  50.0          1      m     Denamrk          NaN     NaN
# 10    Niki    karimi  28.0          3      F          UK          NaN     NaN
#
#    mobile number      Type
# 1       542121214  Student
# 5      5822222443  Student
# 10     5822222448  Student

# %%
pp_df.loc[[1,5,10]]
# Out:
#       name last name   age  course_id Gender nationality  postal code address  \
# 1     Mary     Noori   1.0          2      f         USA       1400.0     NaN
# 5   Jørgen    karimi  50.0          1      m     Denamrk          NaN     NaN
# 10    Niki    karimi  28.0          3      F          UK          NaN     NaN
#
#    mobile number      Type
# 1       542121214  Student
# 5      5822222443  Student
# 10     5822222448  Student

# %%
pp_df.loc[1:10, ['name', 'last name', 'age']]
# Out:
#         name   last name   age
# 1       Mary       Noori   1.0
# 2        Joe       juicy  20.0
# 3        Ati     Heidari  34.0
# 4    AmirAli   Jørgensen  19.0
# 5     Jørgen      karimi  50.0
# 6      Bahar    shabnami   NaN
# 7       Raju  raju zadeh  25.0
# 8   Ashwaria    moghadam  30.0
# 9       Nana  emilderson  45.0
# 10      Niki      karimi  28.0

# %%
pp_df.loc[1:10 :3]
# Out:
#        name   last name   age  course_id Gender nationality  postal code  \
# 1      Mary       Noori   1.0          2      f         USA       1400.0
# 4   AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 7      Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 10     Niki      karimi  28.0          3      F          UK          NaN
#
#    address mobile number      Type
# 1      NaN      542121214  Student
# 4      NaN              9      NaN
# 7      NaN     6662222445  Student
# 10     NaN     5822222448  Student

# %%
pp_df.loc[5:, ['name','last name','age']]
# Out:
#         name   last name   age
# 5     Jørgen      karimi  50.0
# 6      Bahar    shabnami   NaN
# 7       Raju  raju zadeh  25.0
# 8   Ashwaria    moghadam  30.0
# 9       Nana  emilderson  45.0
# 10      Niki      karimi  28.0
# 11      Rosa     niknami  30.0
# 12     Mette  fredriksen   NaN
# 13  Louretta        abdi  28.0
# 14      Nana  emilderson  45.0

# %%
pp_df.loc[5: :3]
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 5     Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 8   Ashwaria    moghadam  30.0          2      F       India       2045.0
# 11      Rosa     niknami  30.0          3     F         Iran       2300.0
# 14      Nana  emilderson  45.0         12      f      Danish       5255.0
#
#    address mobile number      Type
# 5      NaN     5822222443  Student
# 8      NaN     7772222446  Student
# 11     NaN     1122222449  Teacher
# 14     NaN     9992222447  Student

# %%
pp_df.loc[5: 3:]
# Out:
# Empty DataFrame
# Columns: [name, last name, age, course_id, Gender, nationality, postal code, address, mobile number , Type]
# Index: []

# %%
pp_df.loc[pp_df['age']==30, ['age']]=50
pp_df[pp_df.age==50]
# Out:
#         name last name   age  course_id Gender nationality  postal code  \
# 5     Jørgen    karimi  50.0          1      m     Denamrk          NaN
# 8   Ashwaria  moghadam  50.0          2      F       India       2045.0
# 11      Rosa   niknami  50.0          3     F         Iran       2300.0
#
#    address mobile number      Type
# 5      NaN     5822222443  Student
# 8      NaN     7772222446  Student
# 11     NaN     1122222449  Teacher

# %%
pp_df.loc[pp_df.age>40, ['name', 'last name', 'age']]
# Out:
#         name   last name   age
# 0       Tala    andersen  90.0
# 5     Jørgen      karimi  50.0
# 8   Ashwaria    moghadam  50.0
# 9       Nana  emilderson  45.0
# 11      Rosa     niknami  50.0
# 14      Nana  emilderson  45.0

# %% [markdown]
# ## Renaming columns

# %%
pp_df.rename(columns ={'name':'first name'},inplace=True)
pp_df
# Out:
#    first name   last name   age  course_id Gender nationality  postal code  \
# 0        Tala    andersen  90.0          1      F     Denmark       2300.0
# 1        Mary       Noori   1.0          2      f         USA       1400.0
# 2         Joe       juicy  20.0          1      m         USA       2000.0
# 3         Ati     Heidari  34.0          2      f        Iran       2500.0
# 4     AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5      Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 6       Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 7        Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 8    Ashwaria    moghadam  50.0          2      F       India       2045.0
# 9        Nana  emilderson  45.0         12      f      Sweden       5255.0
# 10       Niki      karimi  28.0          3      F          UK          NaN
# ...

# %% [markdown]
# ## Cahanging Dataframe

# %%
sdf = student_df.copy()

# %%
s_df=student_df

# %%
s_df
# Out:
#    id      name   lastname nationality
# 0   1     Bahar       zare        Iran
# 1   2     Bahar    Heidari        Iran
# 2   3      Tara   Anderson          UK
# 3   4      Raha      Gerde         USA
# 4   5      Anna  Jørgensen     Denmark
# 5   6      Anna  Jørgensen     denmark
# 6   7
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %%
s_df.rename(columns= {'name':'firstname'}, inplace=True)

# %%
s_df
# Out:
#    id firstname   lastname nationality
# 0   1     Bahar       zare        Iran
# 1   2     Bahar    Heidari        Iran
# 2   3      Tara   Anderson          UK
# 3   4      Raha      Gerde         USA
# 4   5      Anna  Jørgensen     Denmark
# 5   6      Anna  Jørgensen     denmark
# 6   7
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %%
student_df
# Out:
#    id firstname   lastname nationality
# 0   1     Bahar       zare        Iran
# 1   2     Bahar    Heidari        Iran
# 2   3      Tara   Anderson          UK
# 3   4      Raha      Gerde         USA
# 4   5      Anna  Jørgensen     Denmark
# 5   6      Anna  Jørgensen     denmark
# 6   7
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %%
sdf
# Out:
#    id      name   lastname nationality
# 0   1     Bahar       zare        Iran
# 1   2     Bahar    Heidari        Iran
# 2   3      Tara   Anderson          UK
# 3   4      Raha      Gerde         USA
# 4   5      Anna  Jørgensen     Denmark
# 5   6      Anna  Jørgensen     denmark
# 6   7
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %%
sdf.loc[1]
# Out:
# id                   2
# name             Bahar
# lastname       Heidari
# nationality       Iran
# Name: 1, dtype: object

# %%
sdf.iloc[1]
# Out:
# id                   2
# name             Bahar
# lastname       Heidari
# nationality       Iran
# Name: 1, dtype: object

# %% [markdown]
# ## Removing Duplicate

# %%
sdf[sdf.duplicated('name')]
# Out:
#    id   name   lastname nationality
# 1   2  Bahar    Heidari        Iran
# 5   6   Anna  Jørgensen     denmark

# %%
sdf.drop_duplicates( 'name', keep='first', inplace=True)

# %%
sdf
# Out:
#    id      name   lastname nationality
# 0   1     Bahar       zare        Iran
# 2   3      Tara   Anderson          UK
# 3   4      Raha      Gerde         USA
# 4   5      Anna  Jørgensen     Denmark
# 6   7
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %% [markdown]
# ## Filling empty records

# %%
sdf['name'].fillna('missing')
# Out:
# 0       Bahar
# 2        Tara
# 3        Raha
# 4        Anna
# 6
# 7     Kashifa
# 8    Victoria
# Name: name, dtype: object

# %%
sdf['name'].unique()
# Out:
# array(['Bahar', 'Tara', 'Raha', 'Anna', ' ', 'Kashifa', 'Victoria'],
#       dtype=object)

# %%
sdf.loc[sdf['name']==' ','name']=np.nan

# %%
sdf.name.replace(' ',np.nan)
# Out:
# 0       Bahar
# 2        Tara
# 3        Raha
# 4        Anna
# 6         NaN
# 7     Kashifa
# 8    Victoria
# Name: name, dtype: object

# %%
sdf.name.fillna('missing',inplace=True)

# %%
sdf
# Out:
#    id      name   lastname nationality
# 0   1     Bahar       zare        Iran
# 2   3      Tara   Anderson          UK
# 3   4      Raha      Gerde         USA
# 4   5      Anna  Jørgensen     Denmark
# 6   7   missing
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %%
sdf['lastname'].unique()
# Out:
# array(['zare', 'Anderson', 'Gerde', 'Jørgensen', ' ', 'Umaar', nan],
#       dtype=object)

# %%
sdf['lastname']=np.where(sdf['lastname']==' ', 'missing',sdf['lastname'])

# %%
sdf
# Out:
#    id      name   lastname nationality
# 0   1     Bahar       zare        Iran
# 2   3      Tara   Anderson          UK
# 3   4      Raha      Gerde         USA
# 4   5      Anna  Jørgensen     Denmark
# 6   7   missing    missing
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %%
sdf['nationality']= np.where(sdf['nationality'] ==' ','India', sdf['nationality'])

# %%
sdf
# Out:
#    id      name   lastname nationality
# 0   1     Bahar       zare        Iran
# 2   3      Tara   Anderson          UK
# 3   4      Raha      Gerde         USA
# 4   5      Anna  Jørgensen     Denmark
# 6   7   missing    missing       India
# 7   8   Kashifa      Umaar       India
# 8   9  Victoria        NaN      Ukrain

# %%
sdf.set_index('name', inplace= True)

# %%
sdf
# Out:
#           id   lastname nationality
# name
# Bahar      1       zare        Iran
# Tara       3   Anderson          UK
# Raha       4      Gerde         USA
# Anna       5  Jørgensen     Denmark
# missing    7    missing       India
# Kashifa    8      Umaar       India
# Victoria   9        NaN      Ukrain

# %%
sdf.loc['Tara']
# Out:
# id                    3
# lastname       Anderson
# nationality          UK
# Name: Tara, dtype: object

# %%
sdf.sort_values(['id','lastname'], ascending=False, inplace=True)

# %%
sdf
# Out:
#           id   lastname nationality
# name
# Victoria   9        NaN      Ukrain
# Kashifa    8      Umaar       India
# missing    7    missing       India
# Anna       5  Jørgensen     Denmark
# Raha       4      Gerde         USA
# Tara       3   Anderson          UK
# Bahar      1       zare        Iran

# %% [markdown]
# ## Resetting index

# %%
df2=sdf.copy()

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    id   lastname nationality
# 0   9        NaN      Ukrain
# 1   8      Umaar       India
# 2   7    missing       India
# 3   5  Jørgensen     Denmark
# 4   4      Gerde         USA
# 5   3   Anderson          UK
# 6   1       zare        Iran

# %%
sdf.reset_index(inplace=True)

# %%
sdf
# Out:
#        name  id   lastname nationality
# 0  Victoria   9        NaN      Ukrain
# 1   Kashifa   8      Umaar       India
# 2   missing   7    missing       India
# 3      Anna   5  Jørgensen     Denmark
# 4      Raha   4      Gerde         USA
# 5      Tara   3   Anderson          UK
# 6     Bahar   1       zare        Iran

# %% [markdown]
# ## Adding column

# %%
sdf['new_col']="hi"

# %%
sdf
# Out:
#        name  id   lastname nationality new_col
# 0  Victoria   9        NaN      Ukrain      hi
# 1   Kashifa   8      Umaar       India      hi
# 2   missing   7    missing       India      hi
# 3      Anna   5  Jørgensen     Denmark      hi
# 4      Raha   4      Gerde         USA      hi
# 5      Tara   3   Anderson          UK      hi
# 6     Bahar   1       zare        Iran      hi

# %% [markdown]
# ## Deleting column

# %%
sdf.drop('new_col', axis=1) # method1
# Out:
#        name  id   lastname nationality
# 0  Victoria   9        NaN      Ukrain
# 1   Kashifa   8      Umaar       India
# 2   missing   7    missing       India
# 3      Anna   5  Jørgensen     Denmark
# 4      Raha   4      Gerde         USA
# 5      Tara   3   Anderson          UK
# 6     Bahar   1       zare        Iran

# %%
sdf.drop(columns="new_col",inplace=True) #method2

# %%
sdf
# Out:
#        name  id   lastname nationality
# 0  Victoria   9        NaN      Ukrain
# 1   Kashifa   8      Umaar       India
# 2   missing   7    missing       India
# 3      Anna   5  Jørgensen     Denmark
# 4      Raha   4      Gerde         USA
# 5      Tara   3   Anderson          UK
# 6     Bahar   1       zare        Iran

# %%
pp_df
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1      F     Denmark       2300.0
# 1       Mary       Noori   1.0          2      f         USA       1400.0
# 2        Joe       juicy  20.0          1      m         USA       2000.0
# 3        Ati     Heidari  34.0          2      f        Iran       2500.0
# 4    AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5     Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 6      Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 7       Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 8   Ashwaria    moghadam  30.0          2      F       India       2045.0
# 9       Nana  emilderson  45.0         12      f      Sweden       5255.0
# 10      Niki      karimi  28.0          3      F          UK          NaN
# 11      Rosa     niknami  30.0          3     F         Iran       2300.0
# ...

# %%
pp_df[pp_df['Gender']=='F']
# Out:
#         name last name   age  course_id Gender nationality  postal code  \
# 0       Tala  andersen  90.0          1      F     Denmark       2300.0
# 6      Bahar  shabnami   NaN          2      F      Turkey       3500.0
# 8   Ashwaria  moghadam  30.0          2      F       India       2045.0
# 10      Niki    karimi  28.0          3      F          UK          NaN
#
#          address mobile number      Type
# 0   Else Alfelts      250000025  Student
# 6            NaN     8522222444  Student
# 8            NaN     7772222446  Student
# 10           NaN     5822222448  Student

# %%
pp_df[(pp_df['Gender']=='F')& (pp_df['nationality']=='India')]
# Out:
#        name last name   age  course_id Gender nationality  postal code  \
# 8  Ashwaria  moghadam  30.0          2      F       India       2045.0
#
#   address mobile number      Type
# 8     NaN     7772222446  Student

# %%
pp_df[pp_df['Gender']!='F']
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 1       Mary       Noori   1.0          2      f         USA       1400.0
# 2        Joe       juicy  20.0          1      m         USA       2000.0
# 3        Ati     Heidari  34.0          2      f        Iran       2500.0
# 4    AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5     Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 7       Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 9       Nana  emilderson  45.0         12      f      Sweden       5255.0
# 11      Rosa     niknami  30.0          3     F         Iran       2300.0
# 12     Mette  fredriksen   NaN          2      f       Nepal       2400.0
# 13  Louretta        abdi  28.0          1      f     ukraine       4000.0
# 14      Nana  emilderson  45.0         12      f      Danish       5255.0
#
#       address   mobile number      Type
# ...

# %%
pp_df[pp_df['Gender'].isin(['F','f'])]
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1      F     Denmark       2300.0
# 1       Mary       Noori   1.0          2      f         USA       1400.0
# 3        Ati     Heidari  34.0          2      f        Iran       2500.0
# 6      Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 8   Ashwaria    moghadam  30.0          2      F       India       2045.0
# 9       Nana  emilderson  45.0         12      f      Sweden       5255.0
# 10      Niki      karimi  28.0          3      F          UK          NaN
# 12     Mette  fredriksen   NaN          2      f       Nepal       2400.0
# 13  Louretta        abdi  28.0          1      f     ukraine       4000.0
# 14      Nana  emilderson  45.0         12      f      Danish       5255.0
#
#          address mobile number      Type
# 0   Else Alfelts      250000025  Student
# 1            NaN      542121214  Student
# ...

# %%
pp_df[~pp_df['Gender'].isin(['F','f'])]
# Out:
#        name   last name   age  course_id Gender nationality  postal code  \
# 2       Joe       juicy  20.0          1      m         USA       2000.0
# 4   AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5    Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 7      Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 11     Rosa     niknami  30.0          3     F         Iran       2300.0
#
#       address   mobile number      Type
# 2   Nørreport  54554254254f454  Student
# 4         NaN                9      NaN
# 5         NaN       5822222443  Student
# 7         NaN       6662222445  Student
# 11        NaN       1122222449  Teacher

# %%
pp_df.Gender.unique()
# Out:
# array(['F', 'f', 'm', 'M', nan, ' F '], dtype=object)

# %%
pp_df[pp_df.Gender==' F ']
# Out:
#     name last name   age  course_id Gender nationality  postal code address  \
# 11  Rosa   niknami  30.0          3     F         Iran       2300.0     NaN
#
#    mobile number      Type
# 11     1122222449  Teacher

# %%
pp_df.Gender.value_counts()
# Out:
# Gender
# f      6
# F      4
# m      2
# M      1
#  F     1
# Name: count, dtype: int64

# %%
pp_df.Gender.iloc[11].strip().upper()
# Out:
# 'F'

# %%
pp_df.Gender = pp_df.Gender.fillna('missing').apply(lambda x: x.strip().upper())

# %%
pp_df
# Out:
#         name   last name   age  course_id   Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1        F     Denmark       2300.0
# 1       Mary       Noori   1.0          2        F         USA       1400.0
# 2        Joe       juicy  20.0          1        M         USA       2000.0
# 3        Ati     Heidari  34.0          2        F        Iran       2500.0
# 4    AmirAli   Jørgensen  19.0          1        M      France       2770.0
# 5     Jørgen      karimi  50.0          1        M     Denamrk          NaN
# 6      Bahar    shabnami   NaN          2        F      Turkey       3500.0
# 7       Raju  raju zadeh  25.0          1  MISSING       India       2300.0
# 8   Ashwaria    moghadam  30.0          2        F       India       2045.0
# 9       Nana  emilderson  45.0         12        F      Sweden       5255.0
# 10      Niki      karimi  28.0          3        F          UK          NaN
# ...

# %%
pp_df = pp_df.fillna('missing').apply(lambda x : x.astype(str).str.upper())

# %%
pp_df
# Out:
#         name   last name      age course_id   Gender nationality postal code  \
# 0       TALA    ANDERSEN     90.0         1        F     DENMARK      2300.0
# 1       MARY       NOORI      1.0         2        F         USA      1400.0
# 2        JOE       JUICY     20.0         1        M         USA      2000.0
# 3        ATI     HEIDARI     34.0         2        F        IRAN      2500.0
# 4    AMIRALI   JØRGENSEN     19.0         1        M      FRANCE      2770.0
# 5     JØRGEN      KARIMI     50.0         1        M     DENAMRK     MISSING
# 6      BAHAR    SHABNAMI  MISSING         2        F      TURKEY      3500.0
# 7       RAJU  RAJU ZADEH     25.0         1  MISSING       INDIA      2300.0
# 8   ASHWARIA    MOGHADAM     30.0         2        F       INDIA      2045.0
# 9       NANA  EMILDERSON     45.0        12        F      SWEDEN      5255.0
# 10      NIKI      KARIMI     28.0         3        F          UK     MISSING
# ...

# %%
pp_df.Gender.unique()
# Out:
# array(['F', 'M', 'MISSING'], dtype=object)

# %%
pp_df.Gender.nunique()
# Out:
# 3

# %%
pp_df.groupby('Type')['age'].min()
# Out:
# Type
# MISSING    19.0
# STUDENT     1.0
# TEACHER    30.0
# Name: age, dtype: object

# %%
pp_df.groupby('Type')['age'].max()
# Out:
# Type
# MISSING       19.0
# STUDENT    MISSING
# TEACHER       30.0
# Name: age, dtype: object

# %%
people_df.groupby('Type')['age'].mean()
# Out:
# Type
# Student    36.0
# Teacher    30.0
# Name: age, dtype: float64

# %%
t=people_df.groupby('Type').agg({'age':['min','mean','max']})

# %%
t
# Out:
#           age
#           min  mean   max
# Type
# Student   1.0  36.0  90.0
# Teacher  30.0  30.0  30.0

# %%
t['age']['min']
# Out:
# Type
# Student     1.0
# Teacher    30.0
# Name: min, dtype: float64

# %%
age_agg_df = people_df.groupby('Type', as_index=False).agg(min_avg=('age','min'),avg_age=('age','mean'), max_age=('age','max'), num_age=('age','count'))

# %%
age_agg_df
# Out:
#       Type  min_avg  avg_age  max_age  num_age
# 0  Student      1.0     36.0     90.0       11
# 1  Teacher     30.0     30.0     30.0        1

# %%
people_df.groupby(['Type','postal code'], as_index=False).agg(min_age=('age','min'),
                                                           max_age=('age','max'),
                                                           avg_age=('age','mean'),
                                                           num_age=('name','count'))
# Out:
#       Type  postal code  min_age  max_age  avg_age  num_age
# 0  Student       1400.0      1.0      1.0      1.0        1
# 1  Student       2000.0     20.0     20.0     20.0        1
# 2  Student       2045.0     30.0     30.0     30.0        1
# 3  Student       2300.0     25.0     90.0     57.5        2
# 4  Student       2400.0      NaN      NaN      NaN        1
# 5  Student       2500.0     34.0     34.0     34.0        1
# 6  Student       3500.0      NaN      NaN      NaN        1
# 7  Student       4000.0     28.0     28.0     28.0        1
# 8  Student       5255.0     45.0     45.0     45.0        2
# 9  Teacher       2300.0     30.0     30.0     30.0        1

# %%
sdf
# Out:
#        name  id   lastname nationality
# 0  Victoria   9        NaN      Ukrain
# 1   Kashifa   8      Umaar       India
# 2   missing   7    missing       India
# 3      Anna   5  Jørgensen     Denmark
# 4      Raha   4      Gerde         USA
# 5      Tara   3   Anderson          UK
# 6     Bahar   1       zare        Iran

# %%
sdf.rename(columns ={'name':'firstname', 'id':'s_id', 'lastname':'familyname'}, inplace=True)

# %%
sdf
# Out:
#   firstname  s_id familyname nationality
# 0  Victoria     9        NaN      Ukrain
# 1   Kashifa     8      Umaar       India
# 2   missing     7    missing       India
# 3      Anna     5  Jørgensen     Denmark
# 4      Raha     4      Gerde         USA
# 5      Tara     3   Anderson          UK
# 6     Bahar     1       zare        Iran

# %%
pp_df
# Out:
#         name   last name      age course_id   Gender nationality postal code  \
# 0       TALA    ANDERSEN     90.0         1        F     DENMARK      2300.0
# 1       MARY       NOORI      1.0         2        F         USA      1400.0
# 2        JOE       JUICY     20.0         1        M         USA      2000.0
# 3        ATI     HEIDARI     34.0         2        F        IRAN      2500.0
# 4    AMIRALI   JØRGENSEN     19.0         1        M      FRANCE      2770.0
# 5     JØRGEN      KARIMI     50.0         1        M     DENAMRK     MISSING
# 6      BAHAR    SHABNAMI  MISSING         2        F      TURKEY      3500.0
# 7       RAJU  RAJU ZADEH     25.0         1  MISSING       INDIA      2300.0
# 8   ASHWARIA    MOGHADAM     30.0         2        F       INDIA      2045.0
# 9       NANA  EMILDERSON     45.0        12        F      SWEDEN      5255.0
# 10      NIKI      KARIMI     28.0         3        F          UK     MISSING
# ...

# %%
course_df
# Out:
#    Course_id            name
# 0          1  Data Analytics
# 1          2              UI
# 2          3       Front-end

# %%
person_course_df=pp_df.merge(course_df, left_on='course_id', right_on='Course_id', suffixes=['_person','_course'], how='outer')

# %%
person_course_df
# Out:
#    name_person   last name   age  course_id   Gender nationality  postal code  \
# 0         Tala    andersen  90.0          1        F     Denmark       2300.0
# 1          Joe       juicy  20.0          1        M         USA       2000.0
# 2      AmirAli   Jørgensen  19.0          1        M      France       2770.0
# 3       Jørgen      karimi  50.0          1        M     Denamrk          NaN
# 4         Raju  raju zadeh  25.0          1  MISSING       India       2300.0
# 5     Louretta        abdi  28.0          1        F     ukraine       4000.0
# 6         Mary       Noori   1.0          2        F         USA       1400.0
# 7          Ati     Heidari  34.0          2        F        Iran       2500.0
# 8        Bahar    shabnami   NaN          2        F      Turkey       3500.0
# 9     Ashwaria    moghadam  30.0          2        F       India       2045.0
# 10       Mette  fredriksen   NaN          2        F       Nepal       2400.0
# ...

# %%
pp_co_df=pp_df.rename(columns={'course_id':'Course_id'}).merge(course_df, on='Course_id', how='outer', suffixes=['_person','_course'])

# %%
pp_co_df
# Out:
#    name_person   last name   age  Course_id   Gender nationality  postal code  \
# 0         Tala    andersen  90.0          1        F     Denmark       2300.0
# 1          Joe       juicy  20.0          1        M         USA       2000.0
# 2      AmirAli   Jørgensen  19.0          1        M      France       2770.0
# 3       Jørgen      karimi  50.0          1        M     Denamrk          NaN
# 4         Raju  raju zadeh  25.0          1  MISSING       India       2300.0
# 5     Louretta        abdi  28.0          1        F     ukraine       4000.0
# 6         Mary       Noori   1.0          2        F         USA       1400.0
# 7          Ati     Heidari  34.0          2        F        Iran       2500.0
# 8        Bahar    shabnami   NaN          2        F      Turkey       3500.0
# 9     Ashwaria    moghadam  30.0          2        F       India       2045.0
# 10       Mette  fredriksen   NaN          2        F       Nepal       2400.0
# ...

# %%
pp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            15 non-null     object
#  1   last name       15 non-null     object
#  2   age             15 non-null     object
#  3   course_id       15 non-null     object
#  4   Gender          15 non-null     object
#  5   nationality     15 non-null     object
#  6   postal code     15 non-null     object
#  7   address         15 non-null     object
#  8   mobile number   15 non-null     object
#  9   Type            15 non-null     object
# dtypes: object(10)
# memory usage: 1.3+ KB

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9 non-null      int64
#  1   name         9 non-null      object
#  2   lastname     8 non-null      object
#  3   nationality  9 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 420.0+ bytes

# %%
updated_people=pd.concat([person_course_df ,student_df] , ignore_index=True)

# %%
updated_people
# Out:
#    name_person   last name   age  course_id   Gender nationality  postal code  \
# 0         Tala    andersen  90.0        1.0        F     Denmark       2300.0
# 1          Joe       juicy  20.0        1.0        M         USA       2000.0
# 2      AmirAli   Jørgensen  19.0        1.0        M      France       2770.0
# 3       Jørgen      karimi  50.0        1.0        M     Denamrk          NaN
# 4         Raju  raju zadeh  25.0        1.0  MISSING       India       2300.0
# 5     Louretta        abdi  28.0        1.0        F     ukraine       4000.0
# 6         Mary       Noori   1.0        2.0        F         USA       1400.0
# 7          Ati     Heidari  34.0        2.0        F        Iran       2500.0
# 8        Bahar    shabnami   NaN        2.0        F      Turkey       3500.0
# 9     Ashwaria    moghadam  30.0        2.0        F       India       2045.0
# 10       Mette  fredriksen   NaN        2.0        F       Nepal       2400.0
# ...

# %%
updated_people.to_excel('update person info.xlsx', index=False)

# %%
updated_people.to_csv('update people info.csv', index=False)
